# %% [markdown]
# <a href="https://colab.research.google.com/github/Nurfaidah636/PCVK_Genap_2021/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# Accessing My Google Drive
drive.mount('/content/drive')

import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/4X6.jpg')
plt.imshow(img)
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB) #konversi channel BGR -> RGB
plt.imshow(img3)
img_gray = cv.imread('/content/drive/MyDrive/4X6.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray, cmap='magma')
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

black_img = np.zeros(shape=(512,512,3),dtype = np.int16)
plt.imshow(black_img)

cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15) 
plt.imshow(black_img)

cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32) 
vertices

pts = vertices.reshape((-1,1,2))
pts

cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

imgFigSize = cv.cvtColor(img,cv.COLOR_BGR2RGB)
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(imgFigSize)

img_rg = img.copy()
img_rg[:,:,2] = 0
plt.imshow(img_rg)

img_gb = img
img_gb[:,:,0] = 0
plt.imshow(img_gb)

img_f = img[10:100,10:100]
plt.imshow(img_f)

plt.imshow(img[5:30])

img_4 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
cv.rectangle(img_4, pt1=(90,16), pt2=(200,100), color=(100,225,100), thickness=25)
cv.rectangle(img_4, pt1=(220,80), pt2=(132,163), color=(225,225,100),thickness=25)
cv.rectangle(img_4, pt1=(60,50), pt2=(111,132), color=(100,225,255),thickness=25)
cv.rectangle(img_4, pt1=(50,30), pt2=(100,100), color=(125,100,150),thickness=25)
cv.rectangle(img_4, pt1=(222,20), pt2=(140,100), color=(100,150,150),thickness=25)
plt.imshow(img_4)

imgt = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(imgt)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/fotoku/IMG_6522.JPG')
img = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img)

cv.rectangle(img,pt1=(230,40),pt2=(150,200),color=(255,0,0),thickness=8)
plt.imshow(img)
cv.circle(img,center=(190,135),radius=48,color=(150,100,225),thickness=3)
plt.imshow(img)
cv.rectangle(img,pt1=(5,370),pt2=(100,550),color=(0,255,100),thickness=3)
plt.imshow(img)
cv.rectangle(img,pt1=(5,370),pt2=(100,550),color=(0,255,100),thickness=3)
plt.imshow(img)

font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(img,text='Fenti',org=(100,100),fontFace=font,fontScale=2,color=(225,225,100),thickness=3,lineType=cv.LINE_AA)
plt.imshow(img)
